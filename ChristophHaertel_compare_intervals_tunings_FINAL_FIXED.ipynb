# %%
# FINAL VERSION 2025-03-28
# This script 
# 1. prompts user for concert pitch A4 in Hz
# 2. prompts user for two frequencies in Hz
# 3. determines the interval between those frequencies in Cents
# 4. compares frequencies and interval to custom tuning table in semicolon-delimited CSV file. 
# 5. returns note names ±50 Cts. and interval in semitones ±50 Cts for each custom tuning, relative to concert pitch A4.


import csv
import numpy as np

def load_tuning_table(csv_file):
    # Load tuning deviations from a semicolon-delimited CSV file.
    tunings = {}
    with open(csv_file, newline='', encoding='utf-8') as f:
        reader = csv.reader(f, delimiter=';')
        headers = next(reader)[1:]  # Skip first column (tuning names), keep note names
        for row in reader:
            tuning_name = row[0]
            deviations = list(map(float, row[1:]))
            if len(deviations) == 12:
                tunings[tuning_name] = deviations
            else:
                print(f"Warning: {tuning_name} has {len(deviations)} deviations (expected 12). Skipping.")
    return headers, tunings

def frequency_to_midi(frequency, a4):
    # Convert a frequency to the closest MIDI note number.
    return 69 + 12 * np.log2(frequency / a4)

def midi_to_note(midi_number, note_names):
    # Convert a MIDI number to a note name with octave.
    note_index = int(midi_number) % 12
    octave = (int(midi_number) // 12) - 1
    return f"{note_names[note_index]}{octave}"

def find_closest_note(frequency, note_names, tunings, a4):
    # Find the closest note in each tuning, ensuring deviations stay within ±50 cents.
    midi_number = frequency_to_midi(frequency, a4)
    closest_midi = round(midi_number)
    deviation_from_standard = (midi_number - closest_midi) * 100
    
    results = {}
    for tuning, deviations in tunings.items():
        note_index = closest_midi % 12
        tuning_deviation = deviations[note_index]
        total_deviation = deviation_from_standard - tuning_deviation

        # Ensure deviations stay within ±50 cents
        if total_deviation > 50:
            closest_midi += 1
            total_deviation -= 100
        elif total_deviation < -50:
            closest_midi -= 1
            total_deviation += 100
        
        note_name = midi_to_note(closest_midi, note_names)
        results[tuning] = (note_name, tuning_deviation, total_deviation)
    
    return results

def calculate_interval(freq1, freq2, tunedev1, tunedev2):
    # Calculate interval between two frequencies in cents and semitones, for custom tuning.
    if freq2 >= freq1:
        equal_interval_cents = 1200 * np.log2(freq2 / freq1)
        adjusted_interval_cents = equal_interval_cents - tunedev1 + tunedev2 # adjust for tuning deviations
    else: 
        equal_interval_cents = 1200 * np.log2(freq1 / freq2)
        adjusted_interval_cents = equal_interval_cents - tunedev2 + tunedev1 # adjust for tuning deviations
    
    # break up interval into semitones and cents
    semitones = int(round(adjusted_interval_cents / 100))
    remaining_cents = adjusted_interval_cents - (semitones * 100)

    # Ensure remaining cents is within ±50 cents
    if remaining_cents > 50:
        semitones += 1
        remaining_cents -= 100
    elif remaining_cents < -50:
        semitones -= 1
        remaining_cents += 100

    return semitones, remaining_cents

def get_frequency_input(prompt):
    # Prompt user input for a valid frequency.
    while True:
        try:
            value = float(input(prompt))
            if value > 0:
                return value
            else:
                print("Frequency must be greater than 0.")
        except ValueError:
            print("Invalid input. Please enter a number.")

def main():
    csv_file = 'example_temperaments.csv' 
    # example data sourced from http://www.instrument-tuner.com/temperaments.html on 2024/08/26
    
    note_names, tunings = load_tuning_table(csv_file)


    a4 = get_frequency_input("Enter concert pitch in Hz: ")
    freq1 = get_frequency_input("Enter the first frequency in Hz: ")
    freq2 = get_frequency_input("Enter the second frequency in Hz: ")
    print()
    
    print(f"Results for each tuning, at concert pitch A4 = {a4}: ")
    results1 = find_closest_note(freq1, note_names, tunings, a4)
    results2 = find_closest_note(freq2, note_names, tunings, a4)

     
    for tuning in tunings:
        note1, tunedev1, dev1 = results1[tuning]
        note2, tunedev2, dev2 = results2[tuning]
    
        semitones, remaining_cents = calculate_interval(freq1, freq2, tunedev1, tunedev2)

        remaining_cents_abs = abs(remaining_cents) # Ensure returned cent interval is positive
        print(f"{tuning}: \n{note1} ({dev1:+.2f} cents) to {note2} ({dev2:+.2f} cents), \nInterval: {semitones} semitones {remaining_cents_abs:.2f} cents \n")

if __name__ == "__main__":
    main()
# Out:
# Enter concert pitch in Hz:  438
# Enter the first frequency in Hz:  asölgkh
# Invalid input. Please enter a number.
# Enter the first frequency in Hz:  245
# Enter the second frequency in Hz:  .nn
# Invalid input. Please enter a number.
# Enter the second frequency in Hz:  3476
# Results for each tuning, at concert pitch A4 = 438.0:
# Equal Tempered, Perfect Octave:
# B3 (-5.78 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 8.11 cents
#
# Equal Tempered, Perfect Fourth:
# B3 (-5.00 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 7.33 cents
#
# Equal Tempered, Perfect Fifth:
# B3 (-6.34 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 8.67 cents
#
# Equal Tempered, Streched (1.0 Cent):
# B3 (-5.95 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 8.28 cents
#
# Equal Tempered, Streched (1.25 Cent):
# B3 (-5.99 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 8.32 cents
#
# Equal Tempered, Streched (1.5 Cent):
# B3 (-6.03 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 8.36 cents
#
# Just Tempered (Schugk):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Just Tempered (Barbour):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Naturally harmonious (Thirds):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Naturally harmonious:
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Pythagorean:
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Pythagorean (Perfect):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Pythagorean (Fifth chain Cb - E):
# B3 (+13.77 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 11.44 cents
#
# Pythagorean (Fifth chain Db - F#):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Pythagorean (Fifth chain Ebb - G):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Pythagorean (Fifth chain Fb - A):
# B3 (+13.77 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 11.44 cents
#
# Pythagorean (Fifth chain F - A#):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Pythagorean (Fifth chain Gb - B):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Pythagorean (Fifth chain Ab - C#):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Pythagorean (Fifth chain Bb - D#):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Meantone:
# B3 (+0.09 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 2.25 cents
#
# Meantone # (-1/4):
# B3 (+1.06 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 1.27 cents
#
# Meantone b (-1/4):
# B3 (+1.06 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 1.27 cents
#
# Meantone (-1/4) (LargeThird):
# B3 (+1.06 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 1.27 cents
#
# Meantone (Small third):
# B3 (+4.65 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 2.32 cents
#
# Meantone (Homogeneous):
# B3 (-1.09 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 3.42 cents
#
# Meantone (Homogeneous third):
# B3 (+2.60 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 0.27 cents
#
# Meantone (Homogeneous gradated):
# B3 (-2.52 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 4.85 cents
#
# Comma - Temperament (1/7):
# B3 (-3.54 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 5.88 cents
#
# Comma - Temperament (1/8):
# B3 (-4.31 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 6.64 cents
#
# Comma - Temperament (1/9):
# B3 (-4.91 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 7.24 cents
#
# Comma - Temperament (2/9):
# B3 (-0.13 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 2.46 cents
#
# Comma - Temperament (1/10):
# B3 (-5.39 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 7.72 cents
#
# Comma - Temperament (3/11):
# B3 (+2.04 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 0.29 cents
#
# Pythagorei comma (3-Split):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Pythagorei comma (4-Split):
# B3 (-3.82 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 6.16 cents
#
# Pythagorei comma (5-Split):
# B3 (-0.30 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 2.64 cents
#
# Pythagorei comma (6-Split):
# B3 (-1.87 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 4.20 cents
#
# Pythagorei comma (6 & 12-Split):
# B3 (-1.87 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 4.20 cents
#
# Syntonic comma (2-Split):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Syntonic comma (4-Split):
# B3 (+1.07 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 1.27 cents
#
# Syntonic comma (5-Split):
# B3 (-4.61 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 6.94 cents
#
# Diatonic (Chromatic addition):
# B3 (-9.68 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.01 cents
#
# Organ of Freiberg (Silbermann-Orgel, 1985):
# B3 (-1.87 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 4.20 cents
#
# Organ of Fribourg (Manderscheidt-Orgel, 1640):
# B3 (-0.89 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 3.22 cents
#
# Organ of Hamburg (Schnitger-Orgel, 1993):
# B3 (-1.09 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 3.42 cents
#
# Organ of Maihingen (Baumeister-Orgel, 1737):
# B3 (+4.00 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 1.66 cents
#
# Organ of Muri (Evangelien-Orgel):
# B3 (+0.09 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 2.25 cents
#
# Organ of Niederbobritzsch (Göthel-Orgel):
# B3 (+0.09 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 2.25 cents
#
# Organ of Weingarten (Gabler-Orgel, 1750):
# B3 (-1.51 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 3.84 cents
#
# Organ of Weingarten (Gabler-Orgel, 1983):
# B3 (-1.87 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 4.20 cents
#
# Agricola (Martin, 1539, 1543, 1545):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Ammerbach (1571):
# B3 (-3.82 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 6.16 cents
#
# Ammerbach (1583, Interpretation 1):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Ammerbach (1583, Interpretation 2):
# B3 (-3.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 6.02 cents
#
# Bach (Billeter, Well-Tempered):
# B3 (-0.89 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 3.22 cents
#
# Bach (Kelletats, 1966):
# B3 (-1.22 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 3.55 cents
#
# Bach (Kellner, Well-Tempered):
# B3 (-4.48 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 6.81 cents
#
# Bach (Kellner, 1977):
# B3 (-5.00 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 7.33 cents
#
# Bach (Klais):
# B3 (-0.08 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 2.41 cents
#
# Barnes (1971):
# B3 (-3.82 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 6.16 cents
#
# Barnes (1977):
# B3 (-5.78 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 8.11 cents
#
# Bendeler (Fractions):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Bendeler III:
# B3 (-3.82 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 6.16 cents
#
# Bermudo (1555):
# B3 (-5.78 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 8.11 cents
#
# Bossart I:
# B3 (-0.89 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 3.22 cents
#
# Bossart II:
# B3 (-7.73 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 10.07 cents
#
# Bossart III:
# B3 (-0.89 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 3.22 cents
#
# Bruder (1829):
# B3 (-0.89 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 3.22 cents
#
# Ganassi (1543):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Goebel (1967):
# B3 (-5.66 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 7.99 cents
#
# Grammateus (1518):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Kelletat (1960):
# B3 (+0.09 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 2.25 cents
#
# Kelletat (1966):
# B3 (+0.09 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 2.25 cents
#
# Kellner:
# B3 (-5.00 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 7.33 cents
#
# Kircher:
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Kirnberger I (1766):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Kirnberger II (1771):
# B3 (+1.06 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 1.27 cents
#
# Kirnberger II (1776):
# B3 (+2.04 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 0.29 cents
#
# Kirnberger III (1779):
# B3 (-4.31 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 6.64 cents
#
# Lambert (1774):
# B3 (-2.99 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 5.32 cents
#
# Lublin (1540):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Malcolm (Alexander, 1721):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Marpurg I:
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Marpurg II:
# B3 (-5.78 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 8.11 cents
#
# Marpurg III:
# B3 (+7.91 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 5.57 cents
#
# Marpurg IV:
# B3 (+5.95 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 3.62 cents
#
# Marpurg V:
# B3 (+0.09 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 2.25 cents
#
# Marpurg VI:
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Marpurg VII:
# B3 (-1.87 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 4.20 cents
#
# Marpurg VIII:
# B3 (-3.82 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 6.16 cents
#
# Marpurg IX:
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Marpurg X:
# B3 (-5.78 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 8.11 cents
#
# Marpurg XI:
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Marpurg XII:
# B3 (-5.78 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 8.11 cents
#
# Meister:
# B3 (+1.06 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 1.27 cents
#
# Mersenne (Fractions):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Mersenne (Marin, 1636):
# B3 (-9.20 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 11.53 cents
#
# Neidhardt (1724, Grosse Stadt):
# B3 (-7.73 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 10.07 cents
#
# Neidhardt (1732, Dorf):
# B3 (-3.82 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 6.16 cents
#
# Neidthardt I:
# B3 (-3.82 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 6.16 cents
#
# Neidthardt II:
# B3 (-7.73 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 10.07 cents
#
# Neidthardt III:
# B3 (-7.73 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 10.07 cents
#
# Rameau:
# B3 (+2.04 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 0.29 cents
#
# Rameau (-1/4):
# B3 (+1.06 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 1.27 cents
#
# Ramis de Pareia (1482):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Reinhard (Andreas, 1604):
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Rossi (-1/5):
# B3 (-1.09 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 3.42 cents
#
# Rossi (-2/9):
# B3 (-0.13 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 2.46 cents
#
# Salinas (-1/3):
# B3 (+4.65 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 2.32 cents
#
# Schlick (Barbour):
# B3 (-1.87 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 4.20 cents
#
# Schlick (Dupont):
# B3 (+1.07 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 1.27 cents
#
# Schlick (Lange):
# B3 (-1.62 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 3.96 cents
#
# Schlick (Ratte):
# B3 (-1.87 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 4.20 cents
#
# Schlick (Schugk):
# B3 (-0.30 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 2.64 cents
#
# Schlick (Tessmer):
# B3 (-0.89 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 3.22 cents
#
# Schlick (Vogel):
# B3 (-0.30 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 2.64 cents
#
# Schneegass I (1590):
# B3 (+1.11 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 1.22 cents
#
# Schneegass II (1590):
# B3 (-2.02 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 4.35 cents
#
# Schneegass III (1590):
# B3 (-1.46 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 3.79 cents
#
# Silbermann (-1/6):
# B3 (-2.52 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 4.85 cents
#
# Silbermann (1/6):
# B3 (-1.87 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 4.20 cents
#
# Sorge:
# B3 (-7.73 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 10.07 cents
#
# Stanhope (1801):
# B3 (-1.87 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 4.20 cents
#
# Trost (Johann Caspar, 1677):
# B3 (+7.91 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 5.57 cents
#
# Valotti (1754):
# B3 (-1.87 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 4.20 cents
#
# Van Zwolle:
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Veroli (Ordinaire):
# B3 (+1.07 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 1.27 cents
#
# Werckmeister I:
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Werckmeister II:
# B3 (-1.87 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 4.20 cents
#
# Werckmeister III:
# B3 (-3.82 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 6.16 cents
#
# Werckmeister IV:
# B3 (-9.69 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 12.02 cents
#
# Wiegleb:
# B3 (-3.82 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 6.16 cents
#
# Wiegleb (1790):
# B3 (-4.80 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 7.13 cents
#
# Young I:
# B3 (-3.82 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 6.16 cents
#
# Young II:
# B3 (-1.87 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 4.20 cents
#
# Zarlino (-2/7):
# B3 (+2.60 cents) to A7 (-13.89 cents),
# Interval: 46 semitones 0.27 cents
